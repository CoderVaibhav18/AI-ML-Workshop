# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### X Axis = Horizontal Axis,  Y Axis = Vertical Axis

# %%
a = np.array([0, 7])
b = np.array([0, 150])
plt.plot(a, b)
plt.show()
